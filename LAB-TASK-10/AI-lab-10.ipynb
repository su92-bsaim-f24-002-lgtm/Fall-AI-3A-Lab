# %% [markdown]
# 1. Read CSV:

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

dataset = pd.read_csv("titanic_big.csv")

# %% [markdown]
# Data Loading:

# %%
df = pd.read_csv("titanic_big.csv")
df
# Out:
#      survived  pclass     sex  age    fare embarked
# 0           0       3    male   69  165.39        C
# 1           1       3  female   34  190.21        S
# 2           0       1    male   52  146.52        Q
# 3           0       1    male   10  124.62        S
# 4           0       2    male   19   86.56        S
# ..        ...     ...     ...  ...     ...      ...
# 195         1       2    male   77   70.64        C
# 196         1       3    male   29   31.21        S
# 197         1       1  female   13   17.36        Q
# 198         0       1  female   46  198.04        C
# 199         0       1  female   35   67.86        S
#
# [200 rows x 6 columns]

# %% [markdown]
# Data Exploration:

# %%
df.head(2)
# Out:
#    survived  pclass     sex  age    fare embarked
# 0         0       3    male   69  165.39        C
# 1         1       3  female   34  190.21        S

# %%
df.tail(2)
# Out:
#      survived  pclass     sex  age    fare embarked
# 198         0       1  female   46  198.04        C
# 199         0       1  female   35   67.86        S

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'fare', 'embarked'], dtype='object')

# %%
df.count()
# Out:
# survived    200
# pclass      200
# sex         200
# age         200
# fare        200
# embarked    200
# dtype: int64

# %%
df.describe()
# Out:
#          survived      pclass         age        fare
# count  200.000000  200.000000  200.000000  200.000000
# mean     0.500000    1.965000   38.110000   96.653700
# std      0.501255    0.835022   22.248661   56.150537
# min      0.000000    1.000000    1.000000    7.840000
# 25%      0.000000    1.000000   18.750000   46.127500
# 50%      0.500000    2.000000   36.000000   93.695000
# 75%      1.000000    3.000000   58.000000  140.297500
# max      1.000000    3.000000   78.000000  199.940000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  200 non-null    int64
#  1   pclass    200 non-null    int64
#  2   sex       200 non-null    object
#  3   age       200 non-null    int64
#  4   fare      200 non-null    float64
#  5   embarked  200 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.5+ KB

# %%
df.shape
print(f"Number of Rows: {df.shape[0]} and Number of Columns: {df.shape[1]}")
# Out:
# Number of Rows: 200 and Number of Columns: 6

# %%
df['fare'].unique()
# Out:
# array([165.39, 190.21, 146.52, 124.62,  86.56, 186.88, 173.88,  13.82,
#         10.14,  78.41, 163.06, 197.52,  34.33, 120.86,  79.27, 194.13,
#        169.21, 168.47,  96.4 ,  85.89,  58.31,  15.99, 173.62, 163.52,
#        199.94, 199.34, 113.31, 154.95, 189.23, 170.68,  53.23,  92.86,
#         30.19, 191.04, 123.2 ,  49.59, 135.98, 125.54,  74.84,  27.14,
#        135.96, 106.46, 155.6 , 106.43, 171.18, 112.62, 114.38, 175.95,
#         83.68,  31.13,  10.61, 152.25, 125.96, 142.3 ,  46.53,  31.59,
#          7.84,  73.36, 120.03,  81.49,  90.31, 181.31,  72.91, 105.23,
#        157.81,  82.33, 126.31, 173.16, 190.16,  33.68, 185.68, 100.96,
#         55.36,  94.53, 196.11, 101.06,  69.11, 128.51,  51.83,  19.79,
#         30.13,  29.97,  34.62,  32.07, 129.97,  40.47,  72.41, 179.87,
#         97.42, 135.17,  38.6 ,  42.5 ,  12.97,  37.94,  59.33,  39.52,
#         22.3 ,  28.52,  94.85,  45.24,  76.03, 103.17, 139.63,  12.67,
# ...

# %%
df.nunique()
# Out:
# survived      2
# pclass        3
# sex           2
# age          75
# fare        199
# embarked      3
# dtype: int64

# %%
df.isnull().sum()
# Out:
# survived    0
# pclass      0
# sex         0
# age         0
# fare        0
# embarked    0
# dtype: int64

# %% [markdown]
# Data Preprocessing:

# %% [markdown]
# Manage Null Values:

# %%
df = df.drop('age', axis=1)

# %%
df = df.drop('fare', axis=1)

# %%
# For Object / String Type
def fillnaObjectMode(cols):
    for i in cols:
        df[i] = df[i].fillna(df[i].mode()[0])

columns = ['city', 'street', 'statezip']
fillnaObjectMode(columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\GEO-26-03-2024\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'city'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 7
#       4         df[i] = df[i].fillna(df[i].mode()[0])
# ...

# %% [markdown]
# 2. Print Top 5 rows of dataset:

# %%
print("Top 5 rows of Dataset:")
print(dataset.head())
# Out:
# Top 5 rows of Dataset:
#    survived  pclass     sex  age    fare embarked
# 0         0       3    male   69  165.39        C
# 1         1       3  female   34  190.21        S
# 2         0       1    male   52  146.52        Q
# 3         0       1    male   10  124.62        S
# 4         0       2    male   19   86.56        S

# %% [markdown]
# 3. Print Bottom 5 rows:

# %%
print("\nBottom 5 rows of Dataset:")
print(dataset.tail())
# Out:
# Bottom 5 rows of Dataset:
#      survived  pclass     sex  age    fare embarked
# 195         1       2    male   77   70.64        C
# 196         1       3    male   29   31.21        S
# 197         1       1  female   13   17.36        Q
# 198         0       1  female   46  198.04        C
# 199         0       1  female   35   67.86        S

# %% [markdown]
# 4.Print Number of Rows and Columns:

# %%
print("\nNumber of Rows and Columns:")
print("Rows: ", dataset.shape[0])
print("Columns: ", dataset.shape[1])
# Out:
# Number of Rows and Columns:
# Rows:  200
# Columns:  6

# %% [markdown]
# 5. Print/Determine all null columns:

# %%
print("\nTotal null/missing values in Dataset:")
print(dataset.isnull().sum())
# Out:
# Total null/missing values in Dataset:
# survived    0
# pclass      0
# sex         0
# age         0
# fare        0
# embarked    0
# dtype: int64

# %% [markdown]
# 6. Filling null values using Mean / Median / Mode:

# %%
dataset = dataset.fillna(dataset.mean(numeric_only=True))

# %%
dataset = dataset.fillna(dataset.mode().iloc[0])

# %%
print("\nNull values after filling:")
print(dataset.isnull().sum())
# Out:
# Null values after filling:
# survived    0
# pclass      0
# sex         0
# age         0
# fare        0
# embarked    0
# dtype: int64

# %% [markdown]
# 7. Print datatype of each column:

# %%
print("\nData types of columns:")
print(dataset.dtypes)
# Out:
# Data types of columns:
# survived      int64
# pclass        int64
# sex          object
# age           int64
# fare        float64
# embarked     object
# dtype: object

# %% [markdown]
# 1. Reading csv file:

# %%
data = pd.read_csv('titanic_big.csv')

# %% [markdown]
# 2. Printing rows and colums / shape of dataframe:

# %%
print('We have {} rows.'.format(data.shape[0]))
print('We have {} columns.'.format(data.shape[1]))
# Out:
# We have 200 rows.
# We have 6 columns.

# %% [markdown]
# 3. Checking null values:

# %%
np.sum(pd.isnull(data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 np.sum(pd.isnull(data))
#
# NameError: name 'data' is not defined

# %% [markdown]
# 4. Checking unique values of specific column:

# %%
data['columnname'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\GEO-26-03-2024\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'columnname'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 data['columnname'].unique()
#
# ...

# %% [markdown]
# 5. Filling null values:

# %%
num = data['columnname'].mode()[0]
data['age'] = data['columnname'].fillna(num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 num = data['columnname'].mode()[0]
#       2 data['age'] = data['columnname'].fillna(num)
#
# NameError: name 'data' is not defined

# %% [markdown]
# 6. Type conversion to int:

# %%
data.columnname.astype(np.int64)

# %% [markdown]
# 7. Dropping unnecessary columns:

# %%
data.drop('id', axis=1, inplace=True)

# %% [markdown]
# 8. Check datatypes of all columns:

# %%
data.dtypes

# %% [markdown]
# 9. Splitting into x and y:

# %%
x = data.iloc[:, 0:-1]
x.shape

y = data.iloc[:, -1]
y.shape

# %% [markdown]
# 10. Converting Object columns into Int columns:

# %%
age_columns = x.select_dtypes(['object']).columns
x[age_columns] = x[age_columns_columns].apply(lambda x: pd.factorize(x)[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 age_columns = x.select_dtypes(['object']).columns
#       2 x[age_columns] = x[age_columns_columns].apply(lambda x: pd.factorize(x)[0])
#
# NameError: name 'x' is not defined
