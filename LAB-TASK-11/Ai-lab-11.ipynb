# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# 1. Load Dataset

# %%
data = pd.read_csv("titanic_big.csv")

# %% [markdown]
# 2. Split into X and Y

# %%
X = data.iloc[:, 1:]
Y = data.iloc[:, 0]

# %% [markdown]
# 3. Convert object (categorical) columns to numeric

# %%
cat_cols = X.select_dtypes(include=['object']).columns
X[cat_cols] = X[cat_cols].apply(lambda col: pd.factorize(col)[0])

# %% [markdown]
# 4. Train Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.30, shuffle=False
)

# %% [markdown]
# 5. Choose & Apply Right Model

# %%
model = RandomForestClassifier()
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# 6. Testing / Prediction

# %%
Y_pred = model.predict(X_test)

# %% [markdown]
# 7. Display Accuracy Score

# %%
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy Score:", accuracy)
# Out:
# Accuracy Score: 0.5166666666666667

# %% [markdown]
# 6. Plot Line Graph

# %%
plt.figure(figsize=(16,10))

names = ["Bernoulli", "RandomForest", "GaussianNB", "DecisionTree", "MultinomialNB", "KNN"]

plt.plot(names, [b_accuracy, r_accuracy, g_accuracy, d_accuracy, m_accuracy, k_accuracy], marker='o', label="Accuracy")
plt.plot(names, [b_precision, r_precision, g_precision, d_precision, m_precision, k_precision], marker='o', label="Precision")
plt.plot(names, [b_recall, r_recall, g_recall, d_recall, m_recall, k_recall], marker='o', label="Recall")
plt.plot(names, [b_f1, r_f1, g_f1, d_f1, m_f1, k_f1], marker='o', label="F1 Score")

plt.title("Scores of Applied Classifiers")
plt.legend()
plt.show()

# %% [markdown]
# 7. Plot Bar Graph (F1 Scores)

# %%
plt.figure(figsize=(16,10))

f1_scores = [b_f1, r_f1, g_f1, d_f1, m_f1, k_f1]
plt.bar(names, f1_scores, width=0.7)

plt.ylabel("F1 Score")
plt.title("F1 Scores of All Classifiers")
plt.show()
